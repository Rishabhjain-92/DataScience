# %%
import numpy as np 
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    394     33   John  January      Q1
# 1  2023-01-02       B   West    826     67   Mary  January      Q1
# 2  2023-01-03       C  North    844     13    Bob  January      Q1
# 3  2023-01-04       D  South    966     20  Alice  January      Q1
# 4  2023-01-05       A   East    308     50   John  January      Q1
# 5  2023-01-06       B   West    996     75   Mary  January      Q1
# 6  2023-01-07       C  North    556     66    Bob  January      Q1
# 7  2023-01-08       D  South    165     74  Alice  January      Q1
# 8  2023-01-09       A   East    750     19   John  January      Q1
# 9  2023-01-10       B   West    937     54   Mary  January      Q1
# 10 2023-01-11       C  North    224     41    Bob  January      Q1
# 11 2023-01-12       D  South    271     49  Alice  January      Q1
# 12 2023-01-13       A   East    193     27   John  January      Q1
# 13 2023-01-14       B   West    678     99   Mary  January      Q1
# 14 2023-01-15       C  North    403     92    Bob  January      Q1
# 15 2023-01-16       D  South    260     30  Alice  January      Q1
# 16 2023-01-17       A   East    825     15   John  January      Q1
# 17 2023-01-18       B   West    852     95   Mary  January      Q1
# 18 2023-01-19       C  North    957     70    Bob  January      Q1
# 19 2023-01-20       D  South    460     54  Alice  January      Q1

# %%
pivot = pd.pivot_table(df,values='Sales',index='Region',columns='Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     394.0    NaN    NaN    NaN
# North      NaN    NaN  556.0    NaN
# South      NaN    NaN    NaN  271.0
# West       NaN  852.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df,values=['Sales','Units'],index='Region',columns='Product',aggfunc='median')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     394.0    NaN    NaN    NaN  27.0   NaN   NaN   NaN
# North      NaN    NaN  556.0    NaN   NaN   NaN  66.0   NaN
# South      NaN    NaN    NaN  271.0   NaN   NaN   NaN  49.0
# West       NaN  852.0    NaN    NaN   NaN  75.0   NaN   NaN

# %% [markdown]
# **Cross Tab**

# %%
#yha pr apn counting function use krte h
pd.crosstab(df['Region'],df['Product'])  # ismay count aarha h
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
